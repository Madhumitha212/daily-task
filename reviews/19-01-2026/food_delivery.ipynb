# %%
import numpy as np
import pandas as pd 

res = ["PizzaHut", "Aha Biryani", "KFC king", "kottayam", "Murugan"] 
price = np.random.randint(50,2000,350)
delivery_time = np.random.randint(-1,60,350)
customer_rating = np.random.randint(1,6,350)


data = {  
    "order_id" : np.arange(1,351,1),
    "restaurant" : np.random.choice(res, 350),
    "price": price,
    "delivery_time" : delivery_time,
    "customer_rating" : customer_rating
}
df = pd.DataFrame(data)
df
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 0           1     KFC king    757             15                4
# 1           2     PizzaHut   1674             16                1
# 2           3     kottayam    923             28                2
# 3           4     kottayam   1252             47                5
# 4           5     KFC king    637             29                1
# ..        ...          ...    ...            ...              ...
# 345       346     PizzaHut   1251              0                2
# 346       347  Aha Biryani    532             20                1
# 347       348  Aha Biryani   1357             19                3
# 348       349     kottayam   1760             41                3
# 349       350  Aha Biryani   1246             18                4
#
# [350 rows x 5 columns]

# %%
filter_order = df[(df["delivery_time"]>45) & (df["customer_rating"].between(3,5))]
filter_order
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 3           4     kottayam   1252             47                5
# 9          10     KFC king   1088             55                5
# 17         18      Murugan   1807             53                4
# 25         26      Murugan    698             50                4
# 37         38     PizzaHut    257             54                4
# 44         45  Aha Biryani   1701             50                3
# 49         50     KFC king   1009             55                5
# 53         54     PizzaHut   1740             52                5
# 59         60     KFC king    146             56                5
# 67         68     PizzaHut    447             51                3
# 81         82      Murugan   1345             56                3
# 85         86     kottayam   1162             55                5
# 91         92     PizzaHut    920             47                4
# ...

# %%
poor_performing = df["customer_rating"]<2
poor_performing
df[poor_performing]
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 1           2     PizzaHut   1674             16                1
# 4           5     KFC king    637             29                1
# 10         11  Aha Biryani   1585             39                1
# 16         17     PizzaHut   1044             18                1
# 20         21     KFC king    354             28                1
# ..        ...          ...    ...            ...              ...
# 329       330      Murugan   1277             44                1
# 335       336     KFC king   1287             34                1
# 340       341     PizzaHut    864             12                1
# 343       344      Murugan   1097             31                1
# 346       347  Aha Biryani    532             20                1
#
# [72 rows x 5 columns]

# %%
revenue = df.groupby(df["restaurant"])["price"].sum()
revenue
# Out:
# restaurant
# Aha Biryani     78101
# KFC king        55992
# Murugan        101365
# PizzaHut        51123
# kottayam        81847
# Name: price, dtype: int32

# %%
fifty_percentage = np.percentile(delivery_time,50)
fifty_percentage
# Out:
# 28.0

# %%
delivery_below_fifty = df[df["delivery_time"]<31]
delivery_below_fifty
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 0           1     KFC king    757             15                4
# 1           2     PizzaHut   1674             16                1
# 2           3     kottayam    923             28                2
# 4           5     KFC king    637             29                1
# 5           6     KFC king    529              8                2
# ..        ...          ...    ...            ...              ...
# 344       345     PizzaHut    662             -1                4
# 345       346     PizzaHut   1251              0                2
# 346       347  Aha Biryani    532             20                1
# 347       348  Aha Biryani   1357             19                3
# 349       350  Aha Biryani   1246             18                4
#
# [186 rows x 5 columns]

# %%
df
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 0           1     KFC king    757             15                4
# 1           2     PizzaHut   1674             16                1
# 2           3     kottayam    923             28                2
# 3           4     kottayam   1252             47                5
# 4           5     KFC king    637             29                1
# ..        ...          ...    ...            ...              ...
# 345       346     PizzaHut   1251              0                2
# 346       347  Aha Biryani    532             20                1
# 347       348  Aha Biryani   1357             19                3
# 348       349     kottayam   1760             41                3
# 349       350  Aha Biryani   1246             18                4
#
# [350 rows x 5 columns]

# %%
df[df["delivery_time"]<3]
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 11         12     kottayam    323              0                3
# 39         40      Murugan    658              1                4
# 50         51  Aha Biryani   1021              0                5
# 80         81  Aha Biryani   1558              0                1
# 98         99  Aha Biryani    545              2                5
# 134       135     PizzaHut    683              1                3
# 164       165  Aha Biryani    839              2                5
# 172       173      Murugan    125              0                4
# 179       180      Murugan   1470              2                5
# 181       182     KFC king    160              2                1
# 198       199      Murugan    960              0                2
# 212       213     KFC king    943              1                1
# 216       217      Murugan   1648             -1                1
# ...

# %%
df['delivery_time'] = df['delivery_time'].mask(df['delivery_time'] < 3, df['delivery_time'].median())
df
# Out:
#      order_id   restaurant  price  delivery_time  customer_rating
# 0           1     KFC king    757             15                4
# 1           2     PizzaHut   1674             16                1
# 2           3     kottayam    923             28                2
# 3           4     kottayam   1252             47                5
# 4           5     KFC king    637             29                1
# ..        ...          ...    ...            ...              ...
# 345       346     PizzaHut   1251             28                2
# 346       347  Aha Biryani    532             20                1
# 347       348  Aha Biryani   1357             19                3
# 348       349     kottayam   1760             41                3
# 349       350  Aha Biryani   1246             18                4
#
# [350 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df["delivery_time"],df["customer_rating"])
plt.xlabel("Delivery Time")
plt.ylabel("Customer Rating")
plt.title("Delivery time Vs customer ratings")
plt.grid()
plt.show()

# %%
restaurant_unique = np.unique(data["restaurant"])
restaurant_unique
# Out:
# array(['Aha Biryani', 'KFC king', 'Murugan', 'PizzaHut', 'kottayam'],
#       dtype='<U11')

# %%
fig = plt.bar(restaurant_unique, revenue)
plt.xlabel("Restaurant")
plt.ylabel("Revenue")
plt.title("Revenues of Restaurant")
plt.show()
